# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# Out:
# "''\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport pandas as pd\nimport seaborn as sns\n\nimport tensorflow as tf\nfrom tensorflow.keras.layers import LSTM, Dropout, BatchNormalization, Dense, Activation\nfrom tensorflow.keras.layers import *\nfrom tensorflow.keras.models import Model\nfrom tensorflow.keras.models import load_model\nfrom tensorflow.keras.utils import plot_model\nphysical_devices = tf.config.list_physical_devices('GPU')\n#tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)\n"

# %% [markdown]
# 14th of April - 17:20
#
# Gathered 60 seconds of data,
# Individual finger movements, grouped finger movements (pairs) and all finger closing (grasping).

# %%
data = pd.read_csv("dataset-test-full_hand-60s.csv")

# %%
data.head()
# Out:
#    Channel_1  Channel_2  Channel_3  Channel_4  Channel_5  Channel_6  \
# 0         26        155        217        206         63         36
# 1         25        165        224        182         64         40
# 2         25        167        206        180         57         40
# 3         25        160        207        199         93         40
# 4         24        160        189        212         98         42
#
#    Channel_7  Channel_8    Palm_x     Palm_y  ...  Pinky_MCP_z  Pinky_PIP_x  \
# 0         28         22 -1.323521 -26.056072  ...   130.315430   120.840508
# 1         30         24 -1.372741 -26.092459  ...   130.417664   120.952873
# 2         30         24 -1.470674 -26.166670  ...   130.546982   121.086952
# 3         29         25 -1.563033 -26.240641  ...   130.634567   121.174751
# 4         28         22 -1.662718 -26.319675  ...   130.724792   121.270638
#
#    Pinky_PIP_y  Pinky_PIP_z  Pinky_DIP_x  Pinky_DIP_y  Pinky_DIP_z  \
# 0   149.060608   138.102753   127.402931   118.458565   140.133957
# 1   149.098343   138.170975   127.488365   118.554207   140.177673
# 2   149.156677   138.269287   127.616623   118.703751   140.242477
# 3   149.185791   138.333786   127.716469   118.831955   140.272247
# 4   149.205780   138.394455   127.817085   118.964539   140.290802
#
#    Pinky_TIP_x  Pinky_TIP_y  Pinky_TIP_z
# 0   130.787415   122.895241   114.431587
# 1   130.860641   122.976692   114.515495
# 2   130.973541   123.115433   114.675087
# 3   131.056671   123.232735   114.823090
# 4   131.135437   123.354813   114.986359
#
# [5 rows x 74 columns]

# %% [markdown]
# ![HandPos.png](attachment:HandPos.png)
#
# ```
# 0 = JOINT_MCP – The metacarpophalangeal joint, or knuckle, of the finger.
# 1 = JOINT_PIP – The proximal interphalangeal joint of the finger.This is the middle joint of a finger.
# 2 = JOINT_DIP – The distal interphalangeal joint of the finger. This joint is closest to the tip.
# 3 = JOINT_TIP – The tip of the finger.
# ```

# %%
leap_bone_columns = [
    "Palm_x", "Palm_y", "Palm_z",
    "Wrist_x", "Wrist_y", "Wrist_z",
    'Thumb_MCP_x', 'Thumb_MCP_y', 'Thumb_MCP_z',
    'Thumb_PIP_x', 'Thumb_PIP_y', 'Thumb_PIP_z',
    'Thumb_DIP_x', 'Thumb_DIP_y', 'Thumb_DIP_z',
    'Thumb_TIP_x', 'Thumb_TIP_y', 'Thumb_TIP_z',
    'Index_MCP_x', 'Index_MCP_y', 'Index_MCP_z',
    'Index_PIP_x', 'Index_PIP_y', 'Index_PIP_z',
    'Index_DIP_x', 'Index_DIP_y', 'Index_DIP_z',
    'Index_TIP_x', 'Index_TIP_y', 'Index_TIP_z',
    'Middle_MCP_x', 'Middle_MCP_y', 'Middle_MCP_z',
    'Middle_PIP_x', 'Middle_PIP_y', 'Middle_PIP_z',
    'Middle_DIP_x', 'Middle_DIP_y', 'Middle_DIP_z',
    'Middle_TIP_x', 'Middle_TIP_y', 'Middle_TIP_z',
    'Ring_MCP_x', 'Ring_MCP_y', 'Ring_MCP_z',
    'Ring_PIP_x', 'Ring_PIP_y', 'Ring_PIP_z',
    'Ring_DIP_x', 'Ring_DIP_y', 'Ring_DIP_z',
    'Ring_TIP_x', 'Ring_TIP_y', 'Ring_TIP_z',
    'Pinky_MCP_x', 'Pinky_MCP_y', 'Pinky_MCP_z',
    'Pinky_PIP_x', 'Pinky_PIP_y', 'Pinky_PIP_z',
    'Pinky_DIP_x', 'Pinky_DIP_y', 'Pinky_DIP_z',
    'Pinky_TIP_x', 'Pinky_TIP_y', 'Pinky_TIP_z'
    ]
len(leap_bone_columns)
# Out:
# 66

# %%
data.shape
# Out:
# (2991, 74)

# %% [markdown]
# ## Plotting an example point.

# %%
data.columns
# Out:
# Index(['Channel_1', 'Channel_2', 'Channel_3', 'Channel_4', 'Channel_5',
#        'Channel_6', 'Channel_7', 'Channel_8', 'Palm_x', 'Palm_y', 'Palm_z',
#        'Wrist_x', 'Wrist_y', 'Wrist_z', 'Thumb_MCP_x', 'Thumb_MCP_y',
#        'Thumb_MCP_z', 'Thumb_PIP_x', 'Thumb_PIP_y', 'Thumb_PIP_z',
#        'Thumb_DIP_x', 'Thumb_DIP_y', 'Thumb_DIP_z', 'Thumb_TIP_x',
#        'Thumb_TIP_y', 'Thumb_TIP_z', 'Index_MCP_x', 'Index_MCP_y',
#        'Index_MCP_z', 'Index_PIP_x', 'Index_PIP_y', 'Index_PIP_z',
#        'Index_DIP_x', 'Index_DIP_y', 'Index_DIP_z', 'Index_TIP_x',
#        'Index_TIP_y', 'Index_TIP_z', 'Middle_MCP_x', 'Middle_MCP_y',
#        'Middle_MCP_z', 'Middle_PIP_x', 'Middle_PIP_y', 'Middle_PIP_z',
#        'Middle_DIP_x', 'Middle_DIP_y', 'Middle_DIP_z', 'Middle_TIP_x',
#        'Middle_TIP_y', 'Middle_TIP_z', 'Ring_MCP_x', 'Ring_MCP_y',
#        'Ring_MCP_z', 'Ring_PIP_x', 'Ring_PIP_y', 'Ring_PIP_z', 'Ring_DIP_x',
#        'Ring_DIP_y', 'Ring_DIP_z', 'Ring_TIP_x', 'Ring_TIP_y', 'Ring_TIP_z',
#        'Pinky_MCP_x', 'Pinky_MCP_y', 'Pinky_MCP_z', 'Pinky_PIP_x',
#        'Pinky_PIP_y', 'Pinky_PIP_z', 'Pinky_DIP_x', 'Pinky_DIP_y',
#        'Pinky_DIP_z', 'Pinky_TIP_x', 'Pinky_TIP_y', 'Pinky_TIP_z'],
#       dtype='object')

# %%
channel_cols = ['Channel_1', 'Channel_2', 'Channel_3', 'Channel_4', 'Channel_5','Channel_6', 'Channel_7', 'Channel_8']
bone_df = data.drop(channel_cols, 1)

examp_frame = bone_df.iloc[10].values

# Five finger, 4 joints + palm, wrist. x,y,z
NUM_POINTS = (5 * 4 + 2) * 3
examp_frame = examp_frame.reshape((3, NUM_POINTS//3))
# Out:
# <ipython-input-7-9673482344fd>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   bone_df = data.drop(channel_cols, 1)

# %% [markdown]
# ### Plotting points of the hand

# %%
def plot_points(points, scatter):
    scatter.set_offsets(points[:2].T)
    scatter.set_3d_properties(points[2], zdir='z')


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d', xlim=(-200, 200), ylim=(-200, 150), zlim=(-100, 300))
ax.view_init(elev=45., azim=122)

points_ = np.zeros((3, NUM_POINTS))
patches = ax.scatter(points_[0], points_[1], points_[2], s=10, alpha=1)

plot_points(examp_frame, patches)

# %%
pred = data.iloc[10].drop(channel_cols).values

# Five finger, 4 joints + palm,wrist. x,y,z
NUM_POINTS = (5 * 4 + 2) * 3

# Change the shape by adding a new point on
pred_points = pred.reshape((3, (NUM_POINTS)//3))

# Plotting
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d', xlim=(-200, 200), ylim=(-200, 150), zlim=(-100, 300))
ax.view_init(elev=45., azim=122)

points_ = np.zeros((3, NUM_POINTS))
patches = ax.scatter(points_[0], points_[1], points_[2], s=10, alpha=1)

plot_points(examp_frame, patches)

# %% [markdown]
# ## Plotting the whole hand

# %%
# Plotting the whole hand
def plot_bone_lines(points, ax):
    '''
    Plot the lines for the hand based on a full hand model.
    (22 points, 66 vars)
    '''
    mcps = []

    # Wrist
    wrist = points[:,1]

    # For Each of the 5 fingers
    for i in range(0,5):
        n = 4*i + 2

        # Get each of the bones
        mcp = points[:,n+0]
        pip = points[:,n+1]
        dip = points[:,n+2]
        tip = points[:,n+3]

        # Connect the lowest joint to the middle joint
        bot = plt3d.art3d.Line3D([mcp[0], pip[0]], [mcp[1], pip[1]], [mcp[2], pip[2]])
        ax.add_line(bot)

        # Connect the middle joint to the top joint
        mid = plt3d.art3d.Line3D([pip[0], dip[0]], [pip[1], dip[1]], [pip[2], dip[2]])
        ax.add_line(mid)

        # Connect the top joint to the tip of the finger
        top = plt3d.art3d.Line3D([dip[0], tip[0]], [dip[1], tip[1]], [dip[2], tip[2]])
        ax.add_line(top)

        # Connect each of the fingers together
        mcps.append(mcp)
    for mcp in range(0,4):
        line = plt3d.art3d.Line3D([mcps[mcp][0], mcps[mcp+1][0]],
                                  [mcps[mcp][1], mcps[mcp+1][1]],
                                  [mcps[mcp][2], mcps[mcp+1][2]])
        ax.add_line(line)
    # Create the right side of the hand joining the pinkie mcp to the "wrist"
    line = plt3d.art3d.Line3D([wrist[0], mcps[4][0]],
                                  [wrist[1], mcps[3+1][1]],
                                  [wrist[2], mcps[3+1][2]])
    ax.add_line(line)

    # Generate the "Wrist", note right side is not right.
    line = plt3d.art3d.Line3D([wrist[0], mcps[0][0]],
                                  [wrist[1], mcps[0][1]],
                                  [wrist[2], mcps[0][2]])
    ax.add_line(line)

    # Connext the left hand side of the index finger to the thumb.
    thumb_mcp = points[:,1+2]
    pinky_mcp = points[:,4+2]
    line = plt3d.art3d.Line3D([thumb_mcp[0], pinky_mcp[0]],
                                  [thumb_mcp[1], pinky_mcp[1]],
                                  [thumb_mcp[2], pinky_mcp[2]])
    ax.add_line(line)

# %%
import mpl_toolkits.mplot3d as plt3d

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d', xlim=(-200, 200), ylim=(-200, 150), zlim=(-100, 300))
ax.view_init(elev=45., azim=122)

points_ = np.zeros((3, NUM_POINTS))
sizes = [10]*(NUM_POINTS//3)
sizes[0] = 30
patches = ax.scatter(points_[0], points_[1], points_[2], s=10, alpha=1)

plot_points(examp_frame, patches)
plot_bone_lines(examp_frame,ax)

# %%
def plot_row_bones(row):
    channel_cols = ['Channel_1', 'Channel_2', 'Channel_3', 'Channel_4', 'Channel_5',
       'Channel_6', 'Channel_7', 'Channel_8']
    try:
        bone_df = row.drop(channel_cols)
    except:
        bone_df = row

    # Five finger, 4 joints + palm, wrist. x,y,z
    NUM_POINTS = (5 * 4 + 2) * 3
    examp_frame = bone_df.values.reshape((3, NUM_POINTS//3))

    # Plot setup
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d', xlim=(-200, 200), ylim=(-200, 150), zlim=(-100, 300))
    ax.view_init(elev=45., azim=122)

    points_ = np.zeros((3, NUM_POINTS))
    sizes = [10]*(NUM_POINTS//3)
    sizes[0] = 30
    patches = ax.scatter(points_[0], points_[1], points_[2], s=10, alpha=1)

    # Plot the hand
    plot_points(examp_frame, patches)
    plot_bone_lines(examp_frame,ax)

plot_row_bones(data.iloc[15])

# %%
df = data.copy(deep=True)

# %%
examp = df.iloc[1]
plot_row_bones(examp)

examp = examp - 100
plot_row_bones(examp)

# %%
pred_points
# Out:
# array([[ -2.54038262, -27.01728058,  -2.33715844,  30.41781998,
#          53.0632019 ,  72.5425415 ,  25.16158676,  44.78634644,
#          55.67366028,  63.1270752 ,   6.83079433,  21.49082565,
#          31.19499207,  37.95273209, -12.9173193 ,  -1.99747407,
#           6.28394842,  12.47926426, -30.07982445, -23.65845299,
#         -18.20899582, -12.34996319],
#        [ 42.23242569,  83.87615967,  95.43011475,  65.20063019,
#          44.80765915,  36.48562241,  31.56850052,  -0.77253813,
#         -17.50070381, -28.3409977 ,  23.69394684, -15.61407566,
#         -36.52554703, -48.95720291,  20.84965515, -16.63445282,
#         -37.85514832, -50.88819504,  19.62232971, -10.45976257,
#         -25.47263527, -37.33674622],
#        [144.19047546, 133.29656982, 127.96600342, 120.5625    ,
#         115.68743896, 115.92552185, 156.37071228, 147.36090088,
#         138.40093994, 130.27044678, 154.57821655, 142.60150146,
#         131.15357971, 121.71343994, 149.34906006, 138.80134583,
#         128.32102966, 119.50223541, 140.42851257, 131.5859375 ,
#         123.94785309, 115.6812439 ]])

# %%
print("Correlation Matrix")
print()

def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
print(get_top_abs_correlations(df, 10))
# Out:
# Correlation Matrix
#
# Top Absolute Correlations
# Thumb_MCP_x  Thumb_PIP_y    0.999645
# Thumb_PIP_y  Thumb_DIP_z    0.999546
# Pinky_PIP_y  Pinky_DIP_z    0.999044
# Pinky_MCP_x  Pinky_PIP_y    0.998870
# Ring_DIP_z   Pinky_MCP_x    0.998815
# Thumb_DIP_z  Index_MCP_x    0.998770
# Thumb_MCP_x  Thumb_DIP_z    0.998593
# Pinky_TIP_y  Pinky_TIP_z    0.998220
# Ring_MCP_z   Pinky_MCP_x    0.998052
#              Ring_DIP_z     0.997687
# dtype: float64

# %% [markdown]
# # Making a full hand baseline

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

x_cols = ['Channel_1', 'Channel_2', 'Channel_3', 'Channel_4', 'Channel_5',
       'Channel_6', 'Channel_7', 'Channel_8']

X = df[x_cols]
y = df.drop(x_cols,1)

train_X, test_X, train_y, test_y = train_test_split(X.to_numpy(), y.to_numpy(), test_size=0.25)

# Making our benchmark model
# Just predict the mean average number of bikes.
y_train_mean = train_y.mean()

train_preds = np.ones(train_y.shape) * y_train_mean
preds = np.ones(test_y.shape) * y_train_mean

rmse = np.sqrt(mean_squared_error(train_y, train_preds))
print("Train RMSE: %f" % (rmse))

mae = mean_absolute_error(train_y, train_preds)
print("Train MAE: %f" % (mae))

rmse = np.sqrt(mean_squared_error(test_y, preds))
print("Test RMSE: %f" % (rmse))

mae = mean_absolute_error(test_y, preds)
print("Test MAE: %f" % (mae))

r2_score(test_y, preds)
# Out:
# Train RMSE: 83.130026
# Train MAE: 74.006038
# Test RMSE: 83.082579
# Test MAE: 73.952040
# <ipython-input-17-33a3eb2f22fd>:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   y = df.drop(x_cols,1)
# -44.34153650042752

# %%
X
# Out:
#       Channel_1  Channel_2  Channel_3  Channel_4  Channel_5  Channel_6  \
# 0            26        155        217        206         63         36
# 1            25        165        224        182         64         40
# 2            25        167        206        180         57         40
# 3            25        160        207        199         93         40
# 4            24        160        189        212         98         42
# ...         ...        ...        ...        ...        ...        ...
# 2986         31        136        196        129         63         35
# 2987         33        153        216        131         73         42
# 2988         35        159        227        124         65         40
# 2989         32        144        193        147         66         41
# 2990         36        138        210        143         70         44
#
#       Channel_7  Channel_8
# 0            28         22
# 1            30         24
# 2            30         24
# 3            29         25
# 4            28         22
# ...         ...        ...
# 2986         34         23
# 2987         38         24
# 2988         38         25
# 2989         38         21
# 2990         38         21
#
# [2991 rows x 8 columns]

# %%
y
# Out:
#          Palm_x     Palm_y     Palm_z    Wrist_x    Wrist_y    Wrist_z  \
# 0     -1.323521 -26.056072  -1.447192  31.339682  54.344204  73.968948
# 1     -1.372741 -26.092459  -1.480744  31.301683  54.284824  73.900681
# 2     -1.470674 -26.166670  -1.549118  31.240685  54.182865  73.768768
# 3     -1.563033 -26.240641  -1.617958  31.172728  54.091534  73.670517
# 4     -1.662718 -26.319675  -1.690921  31.093163  53.991615  73.565849
# ...         ...        ...        ...        ...        ...        ...
# 2986 -34.998394 -50.947025 -24.268341   6.003152  27.921375  45.194950
# 2987 -35.024582 -50.951401 -24.269920   6.069254  27.973282  45.183350
# 2988 -35.048061 -50.949505 -24.264589   6.118647  28.016514  45.183865
# 2989 -35.090790 -50.949619 -24.259588   6.220193  28.139288  45.231247
# 2990 -35.120941 -50.944855 -24.250481   6.313409  28.256277  45.300411
#
#       Thumb_MCP_x  Thumb_MCP_y  Thumb_MCP_z  Thumb_PIP_x  ...  Pinky_MCP_z  \
# 0       26.442326    46.319393    57.309357    64.818138  ...   130.315430
# 1       26.393126    46.258076    57.243820    64.750717  ...   130.417664
# 2       26.292677    46.130756    57.105930    64.607620  ...   130.546982
# 3       26.195814    46.019215    56.989487    64.489464  ...   130.634567
# 4       26.089760    45.893440    56.857265    64.354813  ...   130.724792
# ...           ...          ...          ...          ...  ...          ...
# 2986   -10.948850    10.470043    22.487310    30.900105  ...   208.727158
# 2987   -10.959736    10.513408    22.544094    30.958220  ...   208.445648
# 2988   -10.974762    10.571869    22.627546    31.051844  ...   208.160263
# 2989   -10.995328    10.633791    22.707491    31.132689  ...   207.812958
# 2990   -11.015508    10.662545    22.746590    31.172146  ...   207.532684
#
#       Pinky_PIP_x  Pinky_PIP_y  Pinky_PIP_z  Pinky_DIP_x  Pinky_DIP_y  \
# 0      120.840508   149.060608   138.102753   127.402931   118.458565
# 1      120.952873   149.098343   138.170975   127.488365   118.554207
# 2      121.086952   149.156677   138.269287   127.616623   118.703751
# 3      121.174751   149.185791   138.333786   127.716469   118.831955
# 4      121.270638   149.205780   138.394455   127.817085   118.964539
# ...           ...          ...          ...          ...          ...
# 2986   203.895660   212.579742   189.472900   173.113754   161.418930
# 2987   203.523392   212.707825   189.638077   173.359558   161.734894
# 2988   203.165359   212.806824   189.780548   173.632080   162.124176
# 2989   202.706573   213.034866   190.137299   174.130829   162.735687
# 2990   202.366379   213.178253   190.430511   174.592850   163.332733
#
#       Pinky_DIP_z  Pinky_TIP_x  Pinky_TIP_y  Pinky_TIP_z
# 0      140.133957   130.787415   122.895241   114.431587
# 1      140.177673   130.860641   122.976692   114.515495
# 2      140.242477   130.973541   123.115433   114.675087
# 3      140.272247   131.056671   123.232735   114.823090
# 4      140.290802   131.135437   123.354813   114.986359
# ...           ...          ...          ...          ...
# 2986   201.694656   184.502319   173.782684   163.857422
# 2987   201.854538   184.651031   173.945328   164.039474
# 2988   201.977051   184.613358   173.838531   163.882690
# 2989   202.256836   184.986176   174.257538   164.339005
# 2990   202.430893   185.219162   174.515503   164.615540
#
# [2991 rows x 66 columns]

# %% [markdown]
# # Making a baseline Neural Network

# %%
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
x_cols = ['Channel_1', 'Channel_2', 'Channel_3', 'Channel_4', 'Channel_5',
       'Channel_6', 'Channel_7', 'Channel_8']

X = df[x_cols]
y = df.drop(x_cols,1)

rel_hand_scaler = StandardScaler()
emg_scaler = StandardScaler()

ny = rel_hand_scaler.fit_transform(y)
nX = emg_scaler.fit_transform(X)

train_X, test_X, train_y, test_y = train_test_split(nX, ny, test_size=0.25)
# Out:
# <ipython-input-21-77526243965d>:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   y = df.drop(x_cols,1)

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(8,input_dim = train_X.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256,activation='relu'))
NN_model.add(Dense(256,activation='relu'))

# The Output Layer :
NN_model.add(Dense(66,activation='linear'))

# Compile the network :
NN_model.compile(loss='mse', optimizer='Adam')

NN_model.save(f"untrained_neuroleap_model.h5")
NN_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 8)                 72
#
#  dense_5 (Dense)             (None, 256)               2304
#
#  dense_6 (Dense)             (None, 256)               65792
#
#  dense_7 (Dense)             (None, 66)                16962
#
# =================================================================
# Total params: 85130 (332.54 KB)
# Trainable params: 85130 (332.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
history = NN_model.fit(train_X, train_y, epochs=200, batch_size=32, validation_data=(test_X, test_y))
# Out:
# Epoch 1/200
# 71/71 [==============================] - 3s 8ms/step - loss: 0.9554 - val_loss: 0.9371
# Epoch 2/200
# 71/71 [==============================] - 0s 6ms/step - loss: 0.8852 - val_loss: 0.8805
# Epoch 3/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.8440 - val_loss: 0.8447
# Epoch 4/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.8085 - val_loss: 0.8219
# Epoch 5/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.7845 - val_loss: 0.8178
# Epoch 6/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.7648 - val_loss: 0.8263
# Epoch 7/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.7535 - val_loss: 0.8188
# Epoch 8/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.7486 - val_loss: 0.8043
# Epoch 9/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.7241 - val_loss: 0.8155
# Epoch 10/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.7202 - val_loss: 0.7723
# Epoch 11/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.7124 - val_loss: 0.7740
# Epoch 12/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.7009 - val_loss: 0.7726
# Epoch 13/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.6947 - val_loss: 0.7793
# Epoch 14/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.6858 - val_loss: 0.7481
# Epoch 15/200
# 71/71 [==============================] - 1s 9ms/step - loss: 0.6676 - val_loss: 0.7393
# Epoch 16/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.6604 - val_loss: 0.7568
# Epoch 17/200
# 71/71 [==============================] - 1s 9ms/step - loss: 0.6585 - val_loss: 0.7368
# Epoch 18/200
# 71/71 [==============================] - 0s 6ms/step - loss: 0.6619 - val_loss: 0.7262
# Epoch 19/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.6418 - val_loss: 0.7227
# Epoch 20/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.6393 - val_loss: 0.7161
# Epoch 21/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.6317 - val_loss: 0.7357
# Epoch 22/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.6225 - val_loss: 0.7295
# Epoch 23/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.6167 - val_loss: 0.7184
# Epoch 24/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.6094 - val_loss: 0.7075
# Epoch 25/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.5964 - val_loss: 0.7771
# Epoch 26/200
# 71/71 [==============================] - 0s 6ms/step - loss: 0.5964 - val_loss: 0.6980
# Epoch 27/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.5868 - val_loss: 0.6976
# Epoch 28/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.5872 - val_loss: 0.7260
# Epoch 29/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.5779 - val_loss: 0.6914
# Epoch 30/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.5745 - val_loss: 0.6816
# Epoch 31/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.5682 - val_loss: 0.6802
# Epoch 32/200
# 71/71 [==============================] - 0s 6ms/step - loss: 0.5671 - val_loss: 0.6897
# Epoch 33/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.5582 - val_loss: 0.6806
# Epoch 34/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.5532 - val_loss: 0.6750
# Epoch 35/200
# 71/71 [==============================] - 0s 6ms/step - loss: 0.5501 - val_loss: 0.6861
# Epoch 36/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.5443 - val_loss: 0.6934
# Epoch 37/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.5363 - val_loss: 0.7088
# Epoch 38/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.5359 - val_loss: 0.6787
# Epoch 39/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.5243 - val_loss: 0.6702
# Epoch 40/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.5231 - val_loss: 0.6883
# Epoch 41/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.5179 - val_loss: 0.6841
# Epoch 42/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.5136 - val_loss: 0.6766
# Epoch 43/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.5104 - val_loss: 0.6767
# Epoch 44/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.5089 - val_loss: 0.6799
# Epoch 45/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.5049 - val_loss: 0.6748
# Epoch 46/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.5037 - val_loss: 0.6787
# Epoch 47/200
# 71/71 [==============================] - 0s 7ms/step - loss: 0.4915 - val_loss: 0.6777
# Epoch 48/200
# 71/71 [==============================] - 1s 7ms/step - loss: 0.4869 - val_loss: 0.6829
# Epoch 49/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.4916 - val_loss: 0.6899
# Epoch 50/200
# 71/71 [==============================] - 1s 9ms/step - loss: 0.4835 - val_loss: 0.7209
# Epoch 51/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.4957 - val_loss: 0.6683
# Epoch 52/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4698 - val_loss: 0.6658
# Epoch 53/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4644 - val_loss: 0.6907
# Epoch 54/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.4703 - val_loss: 0.6844
# Epoch 55/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.4606 - val_loss: 0.6807
# Epoch 56/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4630 - val_loss: 0.6689
# Epoch 57/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4491 - val_loss: 0.7144
# Epoch 58/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.4687 - val_loss: 0.6902
# Epoch 59/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.4508 - val_loss: 0.6706
# Epoch 60/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4486 - val_loss: 0.6706
# Epoch 61/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4430 - val_loss: 0.6728
# Epoch 62/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4315 - val_loss: 0.6646
# Epoch 63/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4367 - val_loss: 0.6832
# Epoch 64/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4322 - val_loss: 0.6828
# Epoch 65/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4212 - val_loss: 0.6793
# Epoch 66/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4215 - val_loss: 0.6857
# Epoch 67/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4222 - val_loss: 0.6947
# Epoch 68/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4130 - val_loss: 0.6671
# Epoch 69/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4150 - val_loss: 0.6788
# Epoch 70/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4194 - val_loss: 0.6831
# Epoch 71/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4132 - val_loss: 0.6700
# Epoch 72/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4063 - val_loss: 0.6993
# Epoch 73/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.4043 - val_loss: 0.6827
# Epoch 74/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3949 - val_loss: 0.6892
# Epoch 75/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3939 - val_loss: 0.7094
# Epoch 76/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3891 - val_loss: 0.6891
# Epoch 77/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3928 - val_loss: 0.6857
# Epoch 78/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3877 - val_loss: 0.6958
# Epoch 79/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3762 - val_loss: 0.6895
# Epoch 80/200
# 71/71 [==============================] - 0s 7ms/step - loss: 0.3979 - val_loss: 0.6794
# Epoch 81/200
# 71/71 [==============================] - 1s 9ms/step - loss: 0.3719 - val_loss: 0.6762
# Epoch 82/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.3659 - val_loss: 0.6908
# Epoch 83/200
# 71/71 [==============================] - 1s 10ms/step - loss: 0.3674 - val_loss: 0.7043
# Epoch 84/200
# 71/71 [==============================] - 1s 16ms/step - loss: 0.3666 - val_loss: 0.6890
# Epoch 85/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3620 - val_loss: 0.6731
# Epoch 86/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3541 - val_loss: 0.6837
# Epoch 87/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3561 - val_loss: 0.6984
# Epoch 88/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3537 - val_loss: 0.6801
# Epoch 89/200
# 71/71 [==============================] - 0s 7ms/step - loss: 0.3539 - val_loss: 0.7020
# Epoch 90/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.3548 - val_loss: 0.6879
# Epoch 91/200
# 71/71 [==============================] - 1s 7ms/step - loss: 0.3417 - val_loss: 0.6970
# Epoch 92/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.3522 - val_loss: 0.6843
# Epoch 93/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.3478 - val_loss: 0.6893
# Epoch 94/200
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3387 - val_loss: 0.6865
# Epoch 95/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3409 - val_loss: 0.6981
# Epoch 96/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3380 - val_loss: 0.6847
# Epoch 97/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.3357 - val_loss: 0.6824
# Epoch 98/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3334 - val_loss: 0.7005
# Epoch 99/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3402 - val_loss: 0.6927
# Epoch 100/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3262 - val_loss: 0.6956
# Epoch 101/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3172 - val_loss: 0.6828
# Epoch 102/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3166 - val_loss: 0.6898
# Epoch 103/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3178 - val_loss: 0.7331
# Epoch 104/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3188 - val_loss: 0.7072
# Epoch 105/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3114 - val_loss: 0.6951
# Epoch 106/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3029 - val_loss: 0.7030
# Epoch 107/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3215 - val_loss: 0.6903
# Epoch 108/200
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3017 - val_loss: 0.7118
# Epoch 109/200
# 71/71 [==============================] - 1s 9ms/step - loss: 0.3055 - val_loss: 0.6956
# Epoch 110/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.3085 - val_loss: 0.6939
# Epoch 111/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.3027 - val_loss: 0.6949
# Epoch 112/200
# 71/71 [==============================] - 1s 7ms/step - loss: 0.3061 - val_loss: 0.7097
# Epoch 113/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2976 - val_loss: 0.7094
# Epoch 114/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2958 - val_loss: 0.6963
# Epoch 115/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2910 - val_loss: 0.7401
# Epoch 116/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2886 - val_loss: 0.7010
# Epoch 117/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.3028 - val_loss: 0.6975
# Epoch 118/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2981 - val_loss: 0.6997
# Epoch 119/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2852 - val_loss: 0.7012
# Epoch 120/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2850 - val_loss: 0.6896
# Epoch 121/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2809 - val_loss: 0.6945
# Epoch 122/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2848 - val_loss: 0.7111
# Epoch 123/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2787 - val_loss: 0.6988
# Epoch 124/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2733 - val_loss: 0.7363
# Epoch 125/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2725 - val_loss: 0.6925
# Epoch 126/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.2648 - val_loss: 0.6984
# Epoch 127/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2658 - val_loss: 0.7178
# Epoch 128/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2783 - val_loss: 0.7205
# Epoch 129/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2754 - val_loss: 0.7115
# Epoch 130/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2679 - val_loss: 0.7089
# Epoch 131/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2705 - val_loss: 0.7172
# Epoch 132/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2681 - val_loss: 0.7023
# Epoch 133/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2624 - val_loss: 0.7413
# Epoch 134/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2799 - val_loss: 0.7167
# Epoch 135/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2610 - val_loss: 0.7117
# Epoch 136/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2605 - val_loss: 0.7345
# Epoch 137/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.2513 - val_loss: 0.7059
# Epoch 138/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.2489 - val_loss: 0.7080
# Epoch 139/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2471 - val_loss: 0.7423
# Epoch 140/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2483 - val_loss: 0.7087
# Epoch 141/200
# 71/71 [==============================] - 1s 9ms/step - loss: 0.2474 - val_loss: 0.7145
# Epoch 142/200
# 71/71 [==============================] - 1s 7ms/step - loss: 0.2490 - val_loss: 0.7205
# Epoch 143/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.2417 - val_loss: 0.7103
# Epoch 144/200
# 71/71 [==============================] - 1s 7ms/step - loss: 0.2425 - val_loss: 0.7469
# Epoch 145/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.2398 - val_loss: 0.7317
# Epoch 146/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2389 - val_loss: 0.7103
# Epoch 147/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2370 - val_loss: 0.7232
# Epoch 148/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2520 - val_loss: 0.7130
# Epoch 149/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2366 - val_loss: 0.7226
# Epoch 150/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2430 - val_loss: 0.7286
# Epoch 151/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2277 - val_loss: 0.7428
# Epoch 152/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2343 - val_loss: 0.7153
# Epoch 153/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2267 - val_loss: 0.7097
# Epoch 154/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2338 - val_loss: 0.7191
# Epoch 155/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2262 - val_loss: 0.7215
# Epoch 156/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2210 - val_loss: 0.7365
# Epoch 157/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2244 - val_loss: 0.7226
# Epoch 158/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2209 - val_loss: 0.7282
# Epoch 159/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2156 - val_loss: 0.7405
# Epoch 160/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2236 - val_loss: 0.7271
# Epoch 161/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2189 - val_loss: 0.7291
# Epoch 162/200
# 71/71 [==============================] - 0s 6ms/step - loss: 0.2179 - val_loss: 0.7446
# Epoch 163/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2150 - val_loss: 0.7394
# Epoch 164/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.2158 - val_loss: 0.7313
# Epoch 165/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2200 - val_loss: 0.7591
# Epoch 166/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2188 - val_loss: 0.7428
# Epoch 167/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2127 - val_loss: 0.7291
# Epoch 168/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2071 - val_loss: 0.7212
# Epoch 169/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.2045 - val_loss: 0.7429
# Epoch 170/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2125 - val_loss: 0.7353
# Epoch 171/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2030 - val_loss: 0.7288
# Epoch 172/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2072 - val_loss: 0.7526
# Epoch 173/200
# 71/71 [==============================] - 0s 7ms/step - loss: 0.2027 - val_loss: 0.7326
# Epoch 174/200
# 71/71 [==============================] - 1s 7ms/step - loss: 0.2009 - val_loss: 0.7337
# Epoch 175/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.2014 - val_loss: 0.7399
# Epoch 176/200
# 71/71 [==============================] - 1s 9ms/step - loss: 0.2180 - val_loss: 0.7417
# Epoch 177/200
# 71/71 [==============================] - 1s 8ms/step - loss: 0.2025 - val_loss: 0.7416
# Epoch 178/200
# 71/71 [==============================] - 0s 6ms/step - loss: 0.2019 - val_loss: 0.7413
# Epoch 179/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1994 - val_loss: 0.7490
# Epoch 180/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1985 - val_loss: 0.7182
# Epoch 181/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2036 - val_loss: 0.7473
# Epoch 182/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.2000 - val_loss: 0.7767
# Epoch 183/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1943 - val_loss: 0.7371
# Epoch 184/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1897 - val_loss: 0.7356
# Epoch 185/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1900 - val_loss: 0.7358
# Epoch 186/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1925 - val_loss: 0.7370
# Epoch 187/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1903 - val_loss: 0.7359
# Epoch 188/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1889 - val_loss: 0.7373
# Epoch 189/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1834 - val_loss: 0.7381
# Epoch 190/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.1831 - val_loss: 0.7525
# Epoch 191/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1840 - val_loss: 0.7301
# Epoch 192/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1849 - val_loss: 0.7437
# Epoch 193/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1906 - val_loss: 0.7474
# Epoch 194/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1953 - val_loss: 0.7559
# Epoch 195/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.2018 - val_loss: 0.7727
# Epoch 196/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.1945 - val_loss: 0.7574
# Epoch 197/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1808 - val_loss: 0.7894
# Epoch 198/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1862 - val_loss: 0.7432
# Epoch 199/200
# 71/71 [==============================] - 0s 4ms/step - loss: 0.1765 - val_loss: 0.7433
# Epoch 200/200
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1777 - val_loss: 0.7541

# %%
NN_model.save(f"trained_neuroleap_model.h5")

# %%
# Evaluate the model on the test data
mse = NN_model.evaluate(test_X, test_y)
mse
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7612
# 0.7612494230270386

# %% [markdown]
# Note that using wrist as the rel_point gives 0.10, which was a lower loss than using the palm

# %%
# summarize history for loss
# %matplotlib inline
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model MSE')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
prediction = NN_model.predict(train_X) # scaled inputs here
print(prediction)

# Scaling back the prediction
preds = rel_hand_scaler.inverse_transform(prediction)
# Scaling back the goals
goal = rel_hand_scaler.inverse_transform(train_y)

MSE = mean_squared_error(goal, preds)  # first 2 steps, combined
print("MSE: ", MSE)
print("RMSE: ", np.sqrt(MSE))  # 3rd step
MAE = mean_absolute_error(goal, preds)
print("MAE: ", MAE)
# Out:
# 71/71 [==============================] - 0s 3ms/step
# [[-0.8064777  -1.0453959  -1.0759128  ...  1.3263459   1.3749287
#    1.4061092 ]
#  [-1.2118549  -1.1306038  -1.0689749  ...  1.6553154   1.6197516
#    1.5538349 ]
#  [ 0.25577763  0.22941439  0.24759027 ... -0.16489038 -0.15795605
#   -0.17233622]
#  ...
#  [-0.21921507 -0.26978835 -0.27370703 ...  0.21224442  0.23418745
#    0.24629262]
#  [ 1.587693    1.4791807   1.4391717  ... -1.2996336  -1.2244207
#   -1.1786102 ]
#  [ 0.9304715   0.9169494   0.9325724  ... -0.81281215 -0.750482
#   -0.72038037]]
# MSE:  43.99698233193293
# RMSE:  6.633022111521484
# MAE:  4.281854389303479

# %%
prediction = NN_model.predict(test_X) # scaled inputs here
print(prediction)

# Scaling back the prediction
preds = rel_hand_scaler.inverse_transform(prediction)
# Scaling back the goals
goal = rel_hand_scaler.inverse_transform(test_y)

MSE = mean_squared_error(goal, preds)  # first 2 steps, combined
print("MSE: ", MSE)
print("RMSE: ", np.sqrt(MSE))  # 3rd step
MAE = mean_absolute_error(goal, preds)
print("MAE: ", MAE)
# Out:
# 24/24 [==============================] - 0s 3ms/step
# [[-1.2522817  -1.3083825  -1.306686   ...  2.3755383   2.4464037
#    2.5918224 ]
#  [ 2.0315      2.0264213   2.044767   ... -2.2014976  -2.0783303
#   -2.0005229 ]
#  [ 0.47108448  0.39251754  0.39116502 ... -0.27929828 -0.26405117
#   -0.23001666]
#  ...
#  [-0.18200287  0.06836788  0.16231436 ...  0.05118959 -0.05679877
#   -0.0661347 ]
#  [-0.05890276 -0.06330717 -0.07362249 ...  0.39043078  0.46250802
#    0.5225241 ]
#  [ 0.4599052   0.5777635   0.5853303  ... -0.87790006 -1.0532593
#   -1.1964688 ]]
# MSE:  181.08083606211414
# RMSE:  13.456627960306927
# MAE:  8.572063039219001

# %% [markdown]
# # Plot the predicted vs ground truth

# %% [markdown]
# ### Save the model and the scalers

# %%
import joblib

model_name = "NNNonRel-60secs-FULL-StanScaled"

NN_model.save(f"../models/{model_name}.h5")
# Save hand scaler to file.
# Scales the output of the network, the relative position of the hand, min_max
joblib.dump(rel_hand_scaler, f'../models/{model_name}-Hand.gz')

# Scales the input to the network, the emg data.
joblib.dump(emg_scaler, f'../models/{model_name}-EMG.gz')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ['../models/NNNonRel-60secs-FULL-StanScaled-EMG.gz']

# %%
# Making a prediction in the prediction script.
from keras.models import load_model
model = load_model(f"../models/{model_name}.h5")

input_scaler = joblib.load(f'../models/{model_name}-EMG.gz')
output_scaler = joblib.load(f'../models/{model_name}-Hand.gz')

# Get some input data
semg_input = np.array([[ 31, 140, 140,  83,  42,  30,  22,  21]])
# Scale the input
scaled_input = input_scaler.transform(semg_input)
# Get a prediction
pred = model.predict(scaled_input)
# Scale it back to a value
scaled_pred = output_scaler.inverse_transform(pred)
scaled_pred
# Five finger, 4 joints + palm, wrist. x,y,z
NUM_POINTS = (5 * 4 + 2) * 3
pred_points = scaled_pred.reshape((3, NUM_POINTS//3))

# %%
# Plotting pred points
# %matplotlib inline
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d', xlim=(-200, 200), ylim=(-200, 150), zlim=(-100, 300))
ax.view_init(elev=45., azim=122)

points_ = np.zeros((3, NUM_POINTS))
sizes = [10]*(NUM_POINTS//3)
sizes[0] = 30
patches = ax.scatter(points_[0], points_[1], points_[2], s=10, alpha=1)

plot_points(pred_points, patches)
plot_bone_lines(pred_points, ax)

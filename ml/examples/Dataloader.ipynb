# %%
import sys #you need this to add path to utils folder
sys.path.append('../utils') #now you can import from utils folder
# sys.path.append("../..")
from configs import config_general
from dataloaders import dataloader_emg_joints
from datasets import EmgJointPairDataset
# Out:
# c:\Users\saile\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
config = config_general( #these are just example values we will change them according to model
    batch_size = 32 ,
    epochs = 10,
    lr = .005,
    scheduler =None ,
    num_channels_emg = 6,
    num_channels_joints = 3,
    num_sessions = 3,
    seed = 42,
    data_folder_name = "../../datacollection/data",
    dataset_root = "../../datasets",
    dataset_name = "example_dataset",
    train_test_split = .8,
    window_length = 1000,
    emg_transforms = [],
    joint_transforms = [],
    )

# %%
remake_dataset = True
if(remake_dataset):
    dataloader = dataloader_emg_joints(config)
    dataloader.load_data()
    print(dataloader.data.shape)
    dataloader.save_windowed_data()
# Out:
# Loaded ../../datacollection/data/patient1/run0_EMG.wav|../../datacollection/data/patient1/run0_JOINTS.wav
# __________________________________________
# Loaded ../../datacollection/data/patient1/run1_EMG.wav|../../datacollection/data/patient1/run1_JOINTS.wav
# __________________________________________
# Loaded ../../datacollection/data/patient1/run2_EMG.wav|../../datacollection/data/patient1/run2_JOINTS.wav
# __________________________________________
# Loaded ../../datacollection/data/patient2/run0_EMG.wav|../../datacollection/data/patient2/run0_JOINTS.wav
# __________________________________________
# Loaded ../../datacollection/data/patient2/run1_EMG.wav|../../datacollection/data/patient2/run1_JOINTS.wav
# __________________________________________
# Loaded ../../datacollection/data/patient2/run2_EMG.wav|../../datacollection/data/patient2/run2_JOINTS.wav
# __________________________________________
# (2, 3, 100000, 9)
# Saving windowed data to ../../../datasets
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_0.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_1000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_2000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_3000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_4000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_5000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_6000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_7000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_8000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_9000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_10000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_11000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_12000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_13000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_14000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_15000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_16000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_17000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_18000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_19000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_20000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_21000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_22000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_23000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_24000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_25000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_26000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_27000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_28000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_29000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_30000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_31000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_32000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_33000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_34000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_35000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_36000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_37000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_38000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_39000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_40000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_41000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_42000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_43000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_44000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_45000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_46000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_47000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_48000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_49000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_50000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_51000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_52000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_53000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_54000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_55000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_56000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_57000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_58000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_59000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_60000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_61000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_62000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_63000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_64000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_65000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_66000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_67000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_68000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_69000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_70000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_71000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_72000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_73000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_74000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_75000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_76000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_77000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_78000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_79000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_80000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_81000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_82000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_83000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_84000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_85000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_86000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_87000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_88000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_89000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_90000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_91000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_92000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_93000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_94000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_95000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_96000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_97000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_98000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_0_window_99000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_0.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_1000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_2000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_3000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_4000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_5000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_6000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_7000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_8000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_9000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_10000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_11000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_12000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_13000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_14000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_15000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_16000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_17000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_18000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_19000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_20000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_21000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_22000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_23000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_24000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_25000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_26000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_27000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_28000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_29000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_30000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_31000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_32000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_33000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_34000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_35000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_36000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_37000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_38000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_39000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_40000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_41000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_42000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_43000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_44000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_45000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_46000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_47000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_48000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_49000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_50000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_51000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_52000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_53000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_54000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_55000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_56000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_57000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_58000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_59000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_60000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_61000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_62000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_63000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_64000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_65000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_66000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_67000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_68000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_69000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_70000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_71000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_72000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_73000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_74000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_75000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_76000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_77000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_78000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_79000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_80000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_81000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_82000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_83000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_84000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_85000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_86000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_87000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_88000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_89000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_90000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_91000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_92000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_93000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_94000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_95000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_96000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_97000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_98000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_1_window_99000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_0.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_1000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_2000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_3000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_4000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_5000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_6000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_7000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_8000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_9000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_10000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_11000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_12000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_13000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_14000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_15000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_16000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_17000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_18000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_19000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_20000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_21000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_22000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_23000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_24000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_25000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_26000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_27000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_28000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_29000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_30000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_31000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_32000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_33000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window_34000.wav
# Saved window to ../../../datasets\example_dataset\patient_0_session_2_window
# %%
import sys #you need this to add path to utils folder
sys.path.append('../utils') #now you can import from utils folder
# sys.path.append("../..")
from configs import config_general
from dataloaders import dataloader_emg_joints

# %%
# with open("B:/SharedFolder/School/Ucf/SpringSem2024/SeniorDesign/SD1-project/datacollection/data/patient1/run0_EMG .wav","rb") as f:
#     print(f.read(10))

# %%
config = config_general( #these are just example values we will change them according to model
    batch_size = 32 ,
    epochs = 10,
    lr = .005,
    scheduler =None ,
    num_channels_emg = 6,
    num_channels_joints = 2,
    num_sessions = 3,
    seed = 42,
    data_folder_name = "../../datacollection/data",#"b:/SharedFolder/School/Ucf/SpringSem2024/SeniorDesign/SD1-project/datacollection/data",
    train_test_split = .8,
    window_length = 1000)

# %%
dataloader = dataloader_emg_joints(config)
dataloader.load_data()
# Out:
# Sample rate: 250Hz|Data shape: (100000, 7)
# Sample rate: 250Hz|Data shape: (100000, 2)
# Loaded ../../datacollection/data/patient1/run0_EMG.wav|../../datacollection/data/patient1/run0_JOINTS.wav
# __________________________________________
# Sample rate: 250Hz|Data shape: (100000, 7)
# Sample rate: 250Hz|Data shape: (100000, 2)
# Loaded ../../datacollection/data/patient1/run1_EMG.wav|../../datacollection/data/patient1/run1_JOINTS.wav
# __________________________________________
# Sample rate: 250Hz|Data shape: (100000, 7)
# Sample rate: 250Hz|Data shape: (100000, 2)
# Loaded ../../datacollection/data/patient1/run2_EMG.wav|../../datacollection/data/patient1/run2_JOINTS.wav
# __________________________________________
# Sample rate: 250Hz|Data shape: (100000, 7)
# Sample rate: 250Hz|Data shape: (100000, 2)
# Loaded ../../datacollection/data/patient2/run0_EMG.wav|../../datacollection/data/patient2/run0_JOINTS.wav
# __________________________________________
# ...

# %%
dataloader.data.shape
# Out:
# (2, 3, 100000, 9)

# %%
#convert to windowed data
dataloader.window_data().shape
# Out:
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# Windowed data shape: (100, 9)
# ...

# %%
#import models
# from dummy_model import DummyModel

# examplemodels =  [DummyModel(config),DummyModel(config)]
